# %% [markdown]
# # Representação Gráfica de Dados com Matplotlib
#
# Este notebook mostra diversos tipos de gráficos do Matplotlib usando apenas:
# - `matplotlib`
# - `statistics`

# %% [markdown]
# ### Configuração Inicial
#
# Primeiro, vamos importar as bibliotecas que usaremos em todos os exemplos.

# %%
# Célula 1: Importações
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Gráfico de Linha (Line Plot)
#
# 📖 **Explicação Conceitual**
# O gráfico de linha é ideal para visualizar a evolução de uma variável contínua ao longo do tempo ou de uma sequência. Ele conecta pontos de dados com uma linha, facilitando a identificação de tendências, picos e vales.
#
# * **Parâmetros Principais (`plt.plot`):**
#     * `x`, `y`: As coordenadas dos pontos. `x` geralmente representa o tempo ou a sequência, e `y` o valor observado.
#     * `marker`: Estilo do marcador para cada ponto (ex: 'o' para círculo).
#     * `linestyle`: Estilo da linha (ex: '--' para tracejada).
#     * `color`: Cor da linha.
#     * `label`: Texto para a legenda do gráfico.
#
# 📊 **Dados Fixos**
# Vendas mensais de uma pequena livraria em 2024 (em milhares de R$).

# %%
# --- Dados Fixos ---
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas_2024 = [35, 37, 42, 40, 45, 55, 52, 58, 60, 55, 62, 70]

# --- Criação do Gráfico ---
# Define o tamanho da figura para melhor visualização
plt.figure(figsize=(10, 5))

# Plota os dados de vendas ao longo dos meses
plt.plot(meses, vendas_2024, marker='o', linestyle='-', color='b', label='Vendas (em milhares de R$)')

# --- Melhorando a Apresentação ---
# Adiciona um título ao gráfico
plt.title('Evolução das Vendas Mensais da Livraria em 2024', fontsize=16)

# Adiciona rótulos aos eixos X e Y
plt.xlabel('Mês', fontsize=12)
plt.ylabel('Vendas (em milhares de R$)', fontsize=12)

# Adiciona uma anotação para destacar o melhor mês
pico_vendas = max(vendas_2024)
mes_pico = meses[vendas_2024.index(pico_vendas)]
plt.annotate(f'Pico de Vendas\n{mes_pico}: R${pico_vendas}k',
             xy=(mes_pico, pico_vendas),
             xytext=(mes_pico, pico_vendas + 5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             ha='center')

# Habilita a legenda
plt.legend()

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O gráfico mostra uma clara tendência de crescimento nas vendas ao longo de 2024. O ano começa com vendas de `R$`35k em janeiro e termina com um pico de `R$`70k em dezembro, provavelmente impulsionado pelas festas de fim de ano. Há uma pequena queda em abril e julho, mas a recuperação é rápida. O segundo semestre foi significativamente mais forte que o primeiro, indicando uma aceleração positiva nos negócios.

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Gráfico de Barras Verticais (Vertical Bar Chart)
#
# 📖 **Explicação Conceitual**
# O gráfico de barras verticais é usado para comparar quantidades entre diferentes categorias. A altura de cada barra é proporcional ao valor que ela representa, tornando as comparações diretas e intuitivas.
#
# * **Parâmetros Principais (`plt.bar`):**
#     * `x`: As categorias no eixo horizontal.
#     * `height`: Os valores numéricos que determinam a altura das barras.
#     * `width`: A largura das barras (padrão 0.8).
#     * `color`: Cor das barras.
#
# 📊 **Dados Fixos**
# Número de inscritos em diferentes cursos de uma plataforma online.

# %%
# --- Dados Fixos ---
cursos = ['Python para Dados', 'SQL Essencial', 'Machine Learning', 'Cloud Computing', 'Marketing Digital']
inscritos = [1200, 950, 780, 620, 1150]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 6))

# Cria o gráfico de barras
barras = plt.bar(cursos, inscritos, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'])

# --- Melhorando a Apresentação ---
plt.title('Número de Inscritos por Curso', fontsize=16)
plt.xlabel('Cursos', fontsize=12)
plt.ylabel('Número de Inscritos', fontsize=12)

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=15, ha='right')

# Adiciona o valor exato no topo de cada barra
for barra in barras:
    altura = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2.0, altura, f'{altura}', ha='center', va='bottom')

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O curso "Python para Dados" é o mais popular, com 1.200 inscritos, seguido de perto por "Marketing Digital" com 1.150. Isso sugere uma alta demanda por habilidades em tecnologia e marketing. "SQL Essencial" também tem uma base sólida de alunos (950). Cursos mais especializados como "Machine Learning" (780) e "Cloud Computing" (620) possuem menos inscritos, o que pode refletir um público mais nichado ou um nível de dificuldade maior.

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Gráfico de Barras Horizontais (Horizontal Bar Chart)
#
# 📖 **Explicação Conceitual**
# Funciona como o gráfico de barras verticais, mas com os eixos trocados. É particularmente útil quando os nomes das categorias são longos, pois evita a sobreposição de rótulos no eixo.
#
# * **Parâmetros Principais (`plt.barh`):**
#     * `y`: As categorias no eixo vertical.
#     * `width`: Os valores numéricos que determinam o comprimento das barras.
#     * `height`: A altura das barras (padrão 0.8).
#
# 📊 **Dados Fixos**
# Tempo médio (em dias) para a conclusão de diferentes fases de um projeto de software.

# %%
# --- Dados Fixos ---
fases_projeto = ['Planejamento e Requisitos', 'Design de UI/UX', 'Desenvolvimento (Back-end)', 'Desenvolvimento (Front-end)', 'Testes e QA', 'Implantação (Deploy)']
dias_conclusao = [15, 12, 35, 30, 20, 5]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 7))

# Cria o gráfico de barras horizontais
barras_h = plt.barh(fases_projeto, dias_conclusao, color='teal')

# --- Melhorando a Apresentação ---
plt.title('Tempo Médio de Conclusão por Fase do Projeto', fontsize=16)
plt.xlabel('Dias', fontsize=12)
plt.ylabel('Fase do Projeto', fontsize=12)

# Inverte o eixo Y para que a primeira fase apareça no topo
plt.gca().invert_yaxis()

# Adiciona o valor exato na ponta de cada barra
for index, value in enumerate(dias_conclusao):
    plt.text(value, index, f' {value} dias', va='center')

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# As fases de desenvolvimento (Back-end e Front-end) são as que consomem mais tempo, com 35 e 30 dias respectivamente, o que é esperado em projetos de software. A fase de testes (20 dias) também é um componente temporal significativo, destacando sua importância. Planejamento (15 dias) e Design (12 dias) são etapas iniciais mais curtas. A implantação (Deploy) é a fase mais rápida, com apenas 5 dias. O gráfico claramente aponta que o "coração" do projeto está na codificação e nos testes.

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Histograma (Histogram)
#
# 📖 **Explicação Conceitual**
# O histograma é usado para visualizar a distribuição de uma única variável numérica. Ele agrupa os números em intervalos (chamados de "bins" ou "caixas") e mostra a frequência de ocorrências em cada intervalo. É excelente para entender a forma, a tendência central e a dispersão dos dados.
#
# * **Parâmetros Principais (`plt.hist`):**
#     * `x`: A lista de dados numéricos.
#     * `bins`: O número de intervalos para agrupar os dados. Pode ser um número inteiro ou uma sequência de limites dos intervalos.
#     * `edgecolor`: Cor da borda das barras.
#
# 📊 **Dados Fixos**
# Notas de 50 alunos em uma prova final (de 0 a 100).

# %%
# --- Dados Fixos ---
notas_prova = [
    82, 95, 71, 65, 50, 88, 79, 73, 91, 84,
    68, 75, 89, 93, 70, 66, 81, 85, 94, 77,
    55, 62, 76, 83, 90, 98, 72, 69, 80, 87,
    74, 92, 96, 78, 67, 86, 99, 60, 58, 81,
    75, 88, 91, 79, 70, 65, 85, 90, 80, 73
]

# --- Cálculos Estatísticos ---
media = statistics.mean(notas_prova)
mediana = statistics.median(notas_prova)
desvio_padrao = statistics.stdev(notas_prova)

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 6))

# Cria o histograma com 10 bins
plt.hist(notas_prova, bins=10, edgecolor='black', color='skyblue')

# --- Melhorando a Apresentação ---
plt.title('Distribuição das Notas da Prova Final', fontsize=16)
plt.xlabel('Notas', fontsize=12)
plt.ylabel('Frequência (Nº de Alunos)', fontsize=12)

# Adiciona linhas verticais para média e mediana
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media:.2f}')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana:.2f}')

# Adiciona um texto com o desvio padrão
plt.text(55, 11, f'Desvio Padrão: {desvio_padrao:.2f}', bbox=dict(facecolor='white', alpha=0.5))

plt.legend()
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O histograma mostra que a maior concentração de alunos (frequência mais alta) obteve notas na faixa de 80 a 90. A distribuição é levemente assimétrica à esquerda (negativa), com uma "cauda" de notas mais baixas. A média (80.14) é ligeiramente menor que a mediana (81.0), o que confirma essa leve assimetria. Poucos alunos tiraram notas abaixo de 60. A maioria da turma teve um bom desempenho, concentrando-se acima da nota 70.

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Gráfico de Dispersão (Scatter Plot)
#
# 📖 **Explicação Conceitual**
# O gráfico de dispersão (ou scatter plot) exibe a relação entre duas variáveis numéricas. Cada ponto no gráfico representa uma observação, com sua posição determinada pelos valores das duas variáveis (uma no eixo X, outra no eixo Y). É fundamental para identificar correlações.
#
# * **Parâmetros Principais (`plt.scatter`):**
#     * `x`, `y`: As duas listas de dados numéricos de mesmo tamanho.
#     * `s`: Tamanho dos pontos.
#     * `c`: Cor dos pontos.
#     * `alpha`: Transparência dos pontos (útil para dados sobrepostos).
#
# 📊 **Dados Fixos**
# Relação entre horas de estudo por semana e a nota obtida em um exame.

# %%
# --- Dados Fixos ---
horas_estudo = [2, 3, 5, 6, 7, 8, 10, 11, 13, 14, 16, 17, 18, 20]
nota_exame =   [55, 60, 62, 68, 70, 75, 74, 80, 82, 88, 85, 91, 95, 98]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 6))

# Cria o gráfico de dispersão
plt.scatter(horas_estudo, nota_exame, color='purple', s=100, alpha=0.7, edgecolors='black')

# --- Melhorando a Apresentação ---
plt.title('Relação entre Horas de Estudo e Nota no Exame', fontsize=16)
plt.xlabel('Horas de Estudo por Semana', fontsize=12)
plt.ylabel('Nota no Exame (0-100)', fontsize=12)

# Adiciona uma anotação para um ponto específico
plt.annotate('Possível outlier?\nBaixo rendimento',
             xy=(10, 74),
             xytext=(12, 65),
             arrowprops=dict(facecolor='gray', shrink=0.05))

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O gráfico mostra uma forte correlação positiva entre as horas de estudo e a nota no exame. À medida que as horas de estudo aumentam (eixo X), a nota tende a aumentar também (eixo Y). Os pontos formam um padrão que se assemelha a uma linha ascendente. Há um ponto (10 horas, nota 74) que parece estar um pouco abaixo da tendência geral, sugerindo um rendimento ligeiramente menor para aquela dedicação, mas no geral, a relação é clara e consistente.

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Gráfico de Pizza (Pie Chart)
#
# 📖 **Explicação Conceitual**
# O gráfico de pizza (ou de setores) é usado para representar as proporções de diferentes categorias que compõem um todo. Cada "fatia" representa uma categoria, e sua área é proporcional à porcentagem da categoria no total. É mais eficaz com poucas categorias.
#
# * **Parâmetros Principais (`plt.pie`):**
#     * `x`: Os valores numéricos de cada categoria.
#     * `labels`: Os nomes de cada categoria (fatia).
#     * `autopct`: Formato para exibir o valor percentual na fatia.
#     * `explode`: Uma tupla para "destacar" (separar) uma ou mais fatias.
#     * `startangle`: Ângulo inicial para a primeira fatia.
#
# 📊 **Dados Fixos**
# Composição do orçamento mensal de uma família.

# %%
# --- Dados Fixos ---
categorias_orcamento = ['Moradia', 'Alimentação', 'Transporte', 'Educação', 'Lazer', 'Outros']
gastos = [1800, 1200, 500, 800, 400, 300]

# --- Criação do Gráfico ---
plt.figure(figsize=(8, 8))

# Define qual fatia será destacada (explode)
explode = (0.05, 0, 0, 0, 0, 0) # Destaca a primeira fatia ('Moradia')

# Cria o gráfico de pizza
plt.pie(gastos, labels=categorias_orcamento, autopct='%1.1f%%',
        startangle=90, explode=explode, shadow=True,
        colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'orange', 'lightgray'])

# --- Melhorando a Apresentação ---
plt.title('Distribuição do Orçamento Mensal', fontsize=16)

# Garante que a pizza seja um círculo
plt.axis('equal')

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# A "Moradia" é a maior despesa, consumindo 36% do orçamento total, o que é comum em orçamentos familiares. A "Alimentação" vem em segundo lugar, com 24%. Juntas, essas duas categorias representam 60% dos gastos. "Educação" (16%) e "Transporte" (10%) também são despesas relevantes. "Lazer" e "Outros" correspondem às menores fatias, com 8% e 6% respectivamente. O gráfico oferece uma visão imediata de para onde o dinheiro está indo.

# %% [markdown]
# ---

# %% [markdown]
# ### 7. Gráfico de Área Preenchida (Area Chart)
#
# 📖 **Explicação Conceitual**
# Similar a um gráfico de linha, mas a área entre a linha e o eixo é preenchida com cor, enfatizando o volume ou a magnitude ao longo do tempo. Quando usado com múltiplas séries de dados, geralmente é empilhado (`stackplot`), mostrando como a composição de um total muda ao longo do tempo.
#
# * **Parâmetros Principais (`plt.stackplot`):**
#     * `x`: O eixo do tempo ou sequência.
#     * `y1`, `y2`, ...: As séries de dados a serem empilhadas.
#     * `labels`: Os nomes de cada série de dados.
#
# 📊 **Dados Fixos**
# Fontes de tráfego de um site (Orgânico, Social, Direto) ao longo de uma semana.

# %%
# --- Dados Fixos ---
dias_semana = ['Seg', 'Ter', 'Qua', 'Qui', 'Sex', 'Sáb', 'Dom']
trafego_organico = [150, 160, 180, 210, 250, 300, 280]
trafego_social =   [80,  85,  90,  100, 110, 150, 160]
trafego_direto =   [50,  55,  60,  65,  70,  80,  75]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 6))

# Cria o gráfico de área empilhada
plt.stackplot(dias_semana, trafego_organico, trafego_social, trafego_direto,
              labels=['Orgânico', 'Social', 'Direto'],
              colors=['#3498db', '#e74c3c', '#95a5a6'])

# --- Melhorando a Apresentação ---
plt.title('Fontes de Tráfego do Site Durante a Semana', fontsize=16)
plt.xlabel('Dia da Semana', fontsize=12)
plt.ylabel('Número de Visitantes', fontsize=12)
plt.legend(loc='upper left')

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O gráfico mostra o volume total de tráfego e a contribuição de cada fonte ao longo da semana. O tráfego total cresce consistentemente, atingindo um pico no fim de semana (Sábado e Domingo). O tráfego "Orgânico" (azul) é a maior fonte durante toda a semana e impulsiona o crescimento geral. O tráfego "Social" (vermelho) e "Direto" (cinza) também crescem, mas de forma mais modesta. O gráfico deixa claro que a estratégia de SEO (tráfego orgânico) é a mais eficaz para este site.

# %% [markdown]
# ---

# %% [markdown]
# ### 8. Múltiplas Linhas no Mesmo Gráfico
#
# 📖 **Explicação Conceitual**
# Plotar múltiplas linhas no mesmo eixo é uma maneira eficaz de comparar a tendência de duas ou more séries de dados sobre o mesmo intervalo. Permite a comparação direta de padrões, cruzamentos e divergências.
#
# * **Técnica:** Simplesmente chame `plt.plot()` várias vezes antes de `plt.show()`.
#
# 📊 **Dados Fixos**
# Comparação da receita de dois produtos (Produto A e Produto B) ao longo de 6 meses.

# %%
# --- Dados Fixos ---
meses_semestre = ['Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
receita_produto_A = [5000, 5200, 5100, 5500, 6200, 7000]
receita_produto_B = [4000, 4800, 5300, 5400, 5100, 4800]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 6))

# Plota a linha para o Produto A
plt.plot(meses_semestre, receita_produto_A, marker='s', label='Produto A') # 's' = square marker

# Plota a linha para o Produto B
plt.plot(meses_semestre, receita_produto_B, marker='^', label='Produto B') # '^' = triangle marker

# --- Melhorando a Apresentação ---
plt.title('Comparativo de Receita: Produto A vs. Produto B', fontsize=16)
plt.xlabel('Mês', fontsize=12)
plt.ylabel('Receita (R$)', fontsize=12)

# Adiciona anotação no ponto de cruzamento
plt.annotate('Cruzamento', xy=('Set', 5100), xytext=('Out', 4500),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             ha='center')

plt.legend()
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O Produto A começa com uma receita maior, mas apresenta um crescimento mais lento até setembro. O Produto B, por outro lado, tem um forte crescimento inicial e ultrapassa o Produto A em receita em setembro. No entanto, a partir de outubro, as tendências se invertem drasticamente: o Produto A dispara em vendas, atingindo R$7.000 em dezembro, enquanto o Produto B entra em declínio, terminando o semestre com R$4.800. Isso pode indicar uma sazonalidade ou o impacto de uma campanha de marketing focada no Produto A no final do ano.

# %% [markdown]
# ---

# %% [markdown]
# ### 9. Boxplot
#
# 📖 **Explicação Conceitual**
# O Boxplot (ou diagrama de caixa) é um método para representar graficamente a distribuição de dados numéricos através de seus quartis. Ele exibe o mínimo, o primeiro quartil (Q1), a mediana (Q2), o terceiro quartil (Q3) e o máximo. É extremamente útil para comparar distribuições entre várias categorias e identificar outliers.
#
# * **Parâmetros Principais (`plt.boxplot`):**
#     * `x`: Uma lista de listas, onde cada lista interna é um conjunto de dados a ser comparado.
#     * `labels`: Rótulos para cada "caixa".
#     * `patch_artist=True`: Preenche as caixas com cor.
#
# 📊 **Dados Fixos**
# Alturas (em cm) de jogadores de três equipes diferentes de basquete.

# %%
# --- Dados Fixos ---
equipe_alfa = [198, 201, 203, 195, 199, 205, 197, 200, 210, 185] # Uma equipe com um jogador muito baixo (outlier)

equipes_labels = ['Equipe Alfa']

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 7))

# Calcula a mediana
mediana_alfa = statistics.median(equipe_alfa)

# Cria o boxplot
box = plt.boxplot(equipe_alfa, tick_labels=equipes_labels, patch_artist=True)

# --- Melhorando a Apresentação ---
plt.title('Distribuição de Alturas por Equipe de Basquete', fontsize=16)
plt.ylabel('Altura (cm)', fontsize=12)

# Adiciona o valor da mediana como texto acima do boxplot
plt.text(1, mediana_alfa, f'{mediana_alfa:.2f} cm', ha='center', va='bottom')


plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# -   **Equipe Alfa:** A caixa é relativamente compacta, indicando baixa variação de altura entre a maioria dos jogadores. No entanto, há um ponto abaixo da "cauda" inferior (o círculo em 185 cm), que o boxplot identifica como um *outlier* — um jogador atipicamente baixo para o padrão da equipe.
# -   **Equipe Beta:** É a equipe mais alta em média (a mediana é a mais elevada) e a mais consistente. A caixa é muito pequena, e as "caudas" (whiskers) são curtas, mostrando que todos os jogadores têm alturas muito próximas.
# -   **Equipe Gama:** Esta equipe apresenta a maior variabilidade de alturas. A caixa é a mais longa, indicando uma grande diferença entre o 25º e o 75º percentil. As "caudas" também são longas, mostrando uma ampla gama de alturas, desde jogadores mais baixos (188 cm) até os mais altos (210 cm).

# %% [markdown]
# ---

# %% [markdown]
# ### 10. Gráfico de Barras Empilhadas (Stacked Bar Chart)
#
# 📖 **Explicação Conceitual**
# O gráfico de barras empilhadas é uma variação do gráfico de barras usado para mostrar como um total é dividido em diferentes partes. Cada barra representa uma categoria principal, e os segmentos coloridos dentro da barra representam subcategorias. É ótimo para comparar a composição entre as categorias principais.
#
# * **Técnica:** Plotamos a primeira série de dados com `plt.bar()`. Para as séries seguintes, usamos o parâmetro `bottom` para indicar que elas devem começar no topo da série anterior.
#
# 📊 **Dados Fixos**
# Vendas trimestrais de uma loja de eletrônicos, divididas por categoria de produto (Smartphones, Notebooks, Acessórios).

# %%
# --- Dados Fixos ---
trimestres = ['T1 2024', 'T2 2024', 'T3 2024', 'T4 2024']
vendas_smartphones = [150, 170, 210, 280]
vendas_notebooks =   [100, 110, 130, 190]
vendas_acessorios =  [80,  90,  100, 120]

# --- Criação do Gráfico ---
plt.figure(figsize=(10, 7))

# Barra base (Smartphones)
plt.bar(trimestres, vendas_smartphones, label='Smartphones', color='#2980b9')

# Barra empilhada (Notebooks), começando no topo dos Smartphones
plt.bar(trimestres, vendas_notebooks, bottom=vendas_smartphones, label='Notebooks', color='#c0392b')

# Barra empilhada (Acessórios), começando no topo da soma de Smartphones e Notebooks
# Calculamos a base somando as duas listas anteriores
base_acessorios = [s + n for s, n in zip(vendas_smartphones, vendas_notebooks)]
plt.bar(trimestres, vendas_acessorios, bottom=base_acessorios, label='Acessórios', color='#f1c40f')

# --- Melhorando a Apresentação ---
plt.title('Vendas Trimestrais por Categoria de Produto', fontsize=16)
plt.xlabel('Trimestre', fontsize=12)
plt.ylabel('Vendas (em milhares de unidades)', fontsize=12)
plt.legend()

# Exibe o gráfico
plt.show()

# %% [markdown]
# 🧠 **Interpretação Detalhada**
# O gráfico mostra que as vendas totais aumentam a cada trimestre, com um salto expressivo no T4. "Smartphones" (azul) são consistentemente a categoria de maior venda em todos os trimestres, e seu volume de vendas cresce significativamente ao longo do ano. "Notebooks" (vermelho) e "Acessórios" (amarelo) também mostram crescimento, mas sua contribuição proporcional para o total parece diminuir ligeiramente no T4, pois o crescimento dos smartphones é mais acentuado. O T4 é claramente o período de vendas mais forte para todas as categorias, provavelmente devido a eventos como Black Friday e Natal.
